# %%
from data_management.data_acquisition import DataAcquisition
from data_management.data_transformation import DataTransformation
from data_management import FROM_CSV
import pandas as pd
from datetime import timedelta
import seaborn as sns
from models.GCONVCheb import *
from trainer import Trainer
import matplotlib.pyplot as plt
# Out:
# /home/kubos/anaconda3/envs/bp/lib/python3.11/site-packages/paramiko/transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ### Data preparation

# %%
da = DataAcquisition()
df = da.get_data(FROM_CSV, fname="../resources/other_leagues.csv")
df['DT'] = pd.to_datetime(df['DT'], format="%Y-%m-%d %H:%M:%S")
data_transform = DataTransformation(df, timedelta(365))
df = df[(df['League'] != 'EuroLeague') & (df['League'] != 'EuroCup')] 
df = df.reset_index()

transform = DataTransformation(df, timedelta(365))
dataset = transform.get_dataset(node_f_extract=False, edge_f_one_hot=True)

team_count = transform.num_teams

# We will use the default implemented setting: 
#
# GCONVLSTM(self, team_count: int,
#                 embed_dim: int = 10,
#                 dense_dims: tuple[int] = (8, 8, 8, 8, 8),
#                 conv_out_dim: int = 16,
#                 dropout_rate: float = 0.1,
#                 activation: str = 'relu',
#                 K: int = 5):
model = GCONVCheb(team_count)
model
# Out:
# 2024-02-24 13:25:18.539 | INFO     | data_management._data_saving_loading:load_data_csv:70 - 21100 rows loaded from ../resources/other_leagues.csv
# GCONVCheb(
#   (act_fn): ReLU()
#   (embedding): Embedding(146, 20)
#   (dense_sequence): Sequential(
#     (lin0): Linear(in_features=32, out_features=8, bias=True)
#     (act0): ReLU()
#     (dropout0): Dropout(p=0.1, inplace=False)
#     (lin1): Linear(in_features=8, out_features=8, bias=True)
#     (act1): ReLU()
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (lin2): Linear(in_features=8, out_features=8, bias=True)
#     (act2): ReLU()
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (lin3): Linear(in_features=8, out_features=8, bias=True)
#     (act3): ReLU()
#     (dropout3): Dropout(p=0.1, inplace=False)
#     (lin4): Linear(in_features=8, out_features=8, bias=True)
#     (act4): ReLU()
#     (dropout4): Dropout(p=0.1, inplace=False)
#     (lin5): Linear(in_features=8, out_features=3, bias=True)
#     (act5): ReLU()
#     (dropout5): Dropout(p=0.1, inplace=False)
#   )
#   (out_layer): Softmax(dim=1)
# )

# %% [markdown]
# ### MODEL
# --------------------------------
# training:

# %%
trainer = Trainer(dataset, model)
training_accuracy = trainer.train(epochs=100, verbose=True)


ax = sns.lineplot(x="index", y="training_accuracy", data=pd.DataFrame(training_accuracy, columns=["training_accuracy"]).reset_index())
ax.set(xlabel="Epoch")
plt.show()
# Out:
# 2024-02-24 13:25:24.393 | INFO     | trainer:train:56 - [TRN] Epoch: 0, training loss: 2.127, training accuracy: 43.85%
# 2024-02-24 13:25:24.472 | INFO     | trainer:train:56 - [TRN] Epoch: 1, training loss: 2.137, training accuracy: 47.49%
# 2024-02-24 13:25:24.551 | INFO     | trainer:train:56 - [TRN] Epoch: 2, training loss: 2.128, training accuracy: 45.53%
# 2024-02-24 13:25:24.631 | INFO     | trainer:train:56 - [TRN] Epoch: 3, training loss: 2.129, training accuracy: 46.09%
# 2024-02-24 13:25:24.707 | INFO     | trainer:train:56 - [TRN] Epoch: 4, training loss: 2.111, training accuracy: 48.60%
# 2024-02-24 13:25:30.532 | INFO     | trainer:train:56 - [TRN] Epoch: 77, training loss: 2.015, training accuracy: 51.68%
# 2024-02-24 13:25:30.602 | INFO     | trainer:train:56 - [TRN] Epoch: 78, training loss: 1.973, training accuracy: 51.96%
# 2024-02-24 13:25:30.670 | INFO     | trainer:train:56 - [TRN] Epoch: 79, training loss: 1.975, training accuracy: 55.59%
# 2024-02-24 13:25:30.744 | INFO     | trainer:train:56 - [TRN] Epoch: 80, training loss: 2.014, training accuracy: 50.00%
# 2024-02-24 13:25:30.818 | INFO     | trainer:train:56 - [TRN] Epoch: 81, training loss: 2.012, training accuracy: 54.19%
# 2024-02-24 13:25:30.894 | INFO     | trainer:train:56 - [TRN] Epoch: 82, training loss: 2.004, training accuracy: 53.91%
# 2024-02-24 13:25:30.964 | INFO     | trainer:train:56 - [TRN] Epoch: 83, training loss: 1.978, training accuracy: 53.07%
# 2024-02-24 13:25:31.031 | INFO     | trainer:train:56 - [TRN] Epoch: 84, training loss: 1.989, training accuracy: 51.96%
# 2024-02-24 13:25:31.099 | INFO     | trainer:train:56 - [TRN] Epoch: 85, training loss: 1.983, training accuracy: 53.63%
# 2024-02-24 13:25:31.167 | INFO     | trainer:train:56 - [TRN] Epoch: 86, training loss: 1.949, training accuracy: 49.72%
# 2024-02-24 13:25:31.235 | INFO     | trainer:train:56 - [TRN] Epoch: 87, training loss: 2.043, training accuracy: 53.35%
# 2024-02-24 13:25:31.308 | INFO     | trainer:train:56 - [TRN] Epoch: 88, training loss: 1.971, training accuracy: 53.91%
# 2024-02-24 13:25:31.383 | INFO     | trainer:train:56 - [TRN] Epoch: 89, training loss: 1.950, training accuracy: 53.35%
# 2024-02-24 13:25:31.461 | INFO     | trainer:train:56 - [TRN] Epoch: 90, training loss: 1.951, training accuracy: 53.07%
# 2024-02-24 13:25:31.533 | INFO     | trainer:train:56 - [TRN] Epoch: 91, training loss: 1.955, training accuracy: 52.79%
# 2024-02-24 13:25:31.603 | INFO     | trainer:train:56 - [TRN] Epoch: 92, training loss: 1.933, training accuracy: 60.06%
# 2024-02-24 13:25:31.674 | INFO     | trainer:train:56 - [TRN] Epoch: 93, training loss: 1.960, training accuracy: 52.23%
# 2024-02-24 13:25:31.747 | INFO     | trainer:train:56 - [TRN] Epoch: 94, training loss: 1.924, training accuracy: 55.59%
# 2024-02-24 13:25:31.817 | INFO     | trainer:train:56 - [TRN] Epoch: 95, training loss: 1.918, training accuracy: 53.07%
# 2024-02-24 13:25:31.894 | INFO     | trainer:train:56 - [TRN] Epoch: 96, training loss: 1.960, training accuracy: 55.87%
# 2024-02-24 13:25:31.971 | INFO     | trainer:train:56 - [TRN] Epoch: 97, training loss: 2.001, training accuracy: 51.68%
# 2024-02-24 13:25:32.046 | INFO     | trainer:train:56 - [TRN] Epoch: 98, training loss: 1.954, training accuracy: 53.91%
# 2024-02-24 13:25:32.114 | INFO     | trainer:train:56 - [TRN] Epoch: 99, training loss: 1.940, training accuracy: 54.75%

# %% [markdown]
# Testing:

# %%
trainer.test(verbose=True)
# Out:
# 2024-02-24 13:25:39.510 | INFO     | trainer:test:75 - [TST] Testing accuracy: 58.57%
# 0.5857058320731146
