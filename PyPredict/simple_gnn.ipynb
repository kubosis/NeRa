# %%
from data_management.data_acquisition import DataAcquisition
from data_management.data_transformation import DataTransformation
from data_management import FROM_CSV
import pandas as pd
from datetime import timedelta
import seaborn as sns
from models.gnn import GCONVCheb
from trainer import Trainer
import matplotlib.pyplot as plt
# Out:
# /home/kubos/anaconda3/envs/bp/lib/python3.11/site-packages/paramiko/transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ### Data preparation

# %%
da = DataAcquisition()
df = da.get_data(FROM_CSV, fname="../resources/other_leagues.csv")
df['DT'] = pd.to_datetime(df['DT'], format="%Y-%m-%d %H:%M:%S")
data_transform = DataTransformation(df, timedelta(365))
df = df[(df['League'] != 'EuroLeague') & (df['League'] != 'EuroCup')] 
df = df.reset_index()

transform = DataTransformation(df, timedelta(365))
dataset = transform.get_dataset(node_f_extract=False, edge_f_one_hot=True)

team_count = transform.num_teams

# We will use the default implemented setting: 
#
# GCONVLSTM(self, team_count: int,
#                 embed_dim: int = 10,
#                 dense_dims: tuple[int] = (8, 8, 8, 8, 8),
#                 conv_out_dim: int = 16,
#                 dropout_rate: float = 0.1,
#                 activation: str = 'relu',
#                 K: int = 5):
model = GCONVCheb(team_count)
model
# Out:
# 2024-02-26 10:26:12.729 | INFO     | data_management._data_saving_loading:load_data_csv:70 - 21100 rows loaded from ../resources/other_leagues.csv
# GCONVCheb(
#   (act_fn): ReLU()
#   (embedding): Embedding(146, 20)
#   (dense_sequence): Sequential(
#     (lin0): Linear(in_features=32, out_features=8, bias=True)
#     (act0): ReLU()
#     (dropout0): Dropout(p=0.1, inplace=False)
#     (lin1): Linear(in_features=8, out_features=8, bias=True)
#     (act1): ReLU()
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (lin2): Linear(in_features=8, out_features=8, bias=True)
#     (act2): ReLU()
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (lin3): Linear(in_features=8, out_features=8, bias=True)
#     (act3): ReLU()
#     (dropout3): Dropout(p=0.1, inplace=False)
#     (lin4): Linear(in_features=8, out_features=8, bias=True)
#     (act4): ReLU()
#     (dropout4): Dropout(p=0.1, inplace=False)
#     (lin5): Linear(in_features=8, out_features=3, bias=True)
#     (act5): ReLU()
#     (dropout5): Dropout(p=0.1, inplace=False)
#   )
#   (out_layer): Softmax(dim=1)
# )

# %% [markdown]
# ### MODEL
# --------------------------------
# training:

# %%
trainer = Trainer(dataset, model)
training_accuracy = trainer.train(epochs=100, verbose=True)


ax = sns.lineplot(x="index", y="training_accuracy", data=pd.DataFrame(training_accuracy, columns=["training_accuracy"]).reset_index())
ax.set(xlabel="Epoch")
plt.show()
# Out:
# 2024-02-26 10:26:13.254 | INFO     | trainer:train:56 - [TRN] Epoch: 0, training loss: 2.160, training accuracy: 43.02%
# 2024-02-26 10:26:13.327 | INFO     | trainer:train:56 - [TRN] Epoch: 1, training loss: 2.141, training accuracy: 45.25%
# 2024-02-26 10:26:13.393 | INFO     | trainer:train:56 - [TRN] Epoch: 2, training loss: 2.153, training accuracy: 44.41%
# 2024-02-26 10:26:13.464 | INFO     | trainer:train:56 - [TRN] Epoch: 3, training loss: 2.146, training accuracy: 43.85%
# 2024-02-26 10:26:13.535 | INFO     | trainer:train:56 - [TRN] Epoch: 4, training loss: 2.140, training accuracy: 45.53%
# 2024-02-26 10:26:13.608 | INFO     | trainer:train:56 - [TRN] Epoch: 5, training loss: 2.164, training accuracy: 41.90%
# 2024-02-26 10:26:13.678 | INFO     | trainer:train:56 - [TRN] Epoch: 6, training loss: 2.140, training accuracy: 43.30%
# 2024-02-26 10:26:13.749 | INFO     | trainer:train:56 - [TRN] Epoch: 7, training loss: 2.125, training accuracy: 43.58%
# 2024-02-26 10:26:13.820 | INFO     | trainer:train:56 - [TRN] Epoch: 8, training loss: 2.136, training accuracy: 43.58%
# 2024-02-26 10:26:13.891 | INFO     | trainer:train:56 - [TRN] Epoch: 9, training loss: 2.118, training accuracy: 47.49%
# 2024-02-26 10:26:13.961 | INFO     | trainer:train:56 - [TRN] Epoch: 10, training loss: 2.135, training accuracy: 45.53%
# 2024-02-26 10:26:14.036 | INFO     | trainer:train:56 - [TRN] Epoch: 11, training loss: 2.126, training accuracy: 44.97%
# 2024-02-26 10:26:14.107 | INFO     | trainer:train:56 - [TRN] Epoch: 12, training loss: 2.120, training accuracy: 46.37%
# 2024-02-26 10:26:14.177 | INFO     | trainer:train:56 - [TRN] Epoch: 13, training loss: 2.135, training accuracy: 44.13%
# 2024-02-26 10:26:14.248 | INFO     | trainer:train:56 - [TRN] Epoch: 14, training loss: 2.128, training accuracy: 44.69%
# 2024-02-26 10:26:14.320 | INFO     | trainer:train:56 - [TRN] Epoch: 15, training loss: 2.130, training accuracy: 46.37%
# 2024-02-26 10:26:14.389 | INFO     | trainer:train:56 - [TRN] Epoch: 16, training loss: 2.125, training accuracy: 45.81%
# 2024-02-26 10:26:14.457 | INFO     | trainer:train:56 - [TRN] Epoch: 17, training loss: 2.117, training accuracy: 44.97%
# 2024-02-26 10:26:14.530 | INFO     | trainer:train:56 - [TRN] Epoch: 18, training loss: 2.130, training accuracy: 43.30%
# 2024-02-26 10:26:14.597 | INFO     | trainer:train:56 - [TRN] Epoch: 19, training loss: 2.128, training accuracy: 45.25%
# 2024-02-26 10:26:14.665 | INFO     | trainer:train:56 - [TRN] Epoch: 20, training loss: 2.115, training accuracy: 41.06%
# 2024-02-26 10:26:14.732 | INFO     | trainer:train:56 - [TRN] Epoch: 21, training loss: 2.115, training accuracy: 43.58%
# 2024-02-26 10:26:14.799 | INFO     | trainer:train:56 - [TRN] Epoch: 22, training loss: 2.099, training accuracy: 47.49%
# 2024-02-26 10:26:14.868 | INFO     | trainer:train:56 - [TRN] Epoch: 23, training loss: 2.104, training accuracy: 44.41%
# 2024-02-26 10:26:14.931 | INFO     | trainer:train:56 - [TRN] Epoch: 24, training loss: 2.105, training accuracy: 44.69%
# 2024-02-26 10:26:14.995 | INFO     | trainer:train:56 - [TRN] Epoch: 25, training loss: 2.110, training accuracy: 44.41%
# 2024-02-26 10:26:15.067 | INFO     | trainer:train:56 - [TRN] Epoch: 26, training loss: 2.106, training accuracy: 43.85%
# 2024-02-26 10:26:15.136 | INFO     | trainer:train:56 - [TRN] Epoch: 27, training loss: 2.099, training accuracy: 45.81%
# 2024-02-26 10:26:15.204 | INFO     | trainer:train:56 - [TRN] Epoch: 28, training loss: 2.107, training accuracy: 41.62%
# 2024-02-26 10:26:15.271 | INFO     | trainer:train:56 - [TRN] Epoch: 29, training loss: 2.099, training accuracy: 45.25%
# 2024-02-26 10:26:15.339 | INFO     | trainer:train:56 - [TRN] Epoch: 30, training loss: 2.092, training accuracy: 43.02%
# 2024-02-26 10:26:15.403 | INFO     | trainer:train:56 - [TRN] Epoch: 31, training loss: 2.109, training accuracy: 42.18%
# 2024-02-26 10:26:15.474 | INFO     | trainer:train:56 - [TRN] Epoch: 32, training loss: 2.129, training accuracy: 43.30%
# 2024-02-26 10:26:15.547 | INFO     | trainer:train:56 - [TRN] Epoch: 33, training loss: 2.098, training accuracy: 46.09%
# 2024-02-26 10:26:15.616 | INFO     | trainer:train:56 - [TRN] Epoch: 34, training loss: 2.102, training accuracy: 42.74%
# 2024-02-26 10:26:15.686 | INFO     | trainer:train:56 - [TRN] Epoch: 35, training loss: 2.080, training accuracy: 46.65%
# 2024-02-26 10:26:15.755 | INFO     | trainer:train:56 - [TRN] Epoch: 36, training loss: 2.098, training accuracy: 43.30%
# 2024-02-26 10:26:15.824 | INFO     | trainer:train:56 - [TRN] Epoch: 37, training loss: 2.091, training accuracy: 45.81%
# 2024-02-26 10:26:15.893 | INFO     | trainer:train:56 - [TRN] Epoch: 38, training loss: 2.099, training accuracy: 45.81%
# 2024-02-26 10:26:15.959 | INFO     | trainer:train:56 - [TRN] Epoch: 39, training loss: 2.090, training accuracy: 47.21%
# 2024-02-26 10:26:16.030 | INFO     | trainer:train:56 - [TRN] Epoch: 40, training loss: 2.078, training accuracy: 43.85%
# 2024-02-26 10:26:16.097 | INFO     | trainer:train:56 - [TRN] Epoch: 41, training loss: 2.096, training accuracy: 44.13%
# 2024-02-26 10:26:16.166 | INFO     | trainer:train:56 - [TRN] Epoch: 42, training loss: 2.073, training accuracy: 44.97%
# 2024-02-26 10:26:16.233 | INFO     | trainer:train:56 - [TRN] Epoch: 43, training loss: 2.065, training accuracy: 46.65%
# 2024-02-26 10:26:16.299 | INFO     | trainer:train:56 - [TRN] Epoch: 44, training loss: 2.089, training accuracy: 43.85%
# 2024-02-26 10:26:16.364 | INFO     | trainer:train:56 - [TRN] Epoch: 45, training loss: 2.079, training accuracy: 44.13%
# 2024-02-26 10:26:16.431 | INFO     | trainer:train:56 - [TRN] Epoch: 46, training loss: 2.079, training accuracy: 45.25%
# 2024-02-26 10:26:16.501 | INFO     | trainer:train:56 - [TRN] Epoch: 47, training loss: 2.126, training accuracy: 43.85%
# 2024-02-26 10:26:16.571 | INFO     | trainer:train:56 - [TRN] Epoch: 48, training loss: 2.067, training accuracy: 45.81%
# 2024-02-26 10:26:16.642 | INFO     | trainer:train:56 - [TRN] Epoch: 49, training loss: 2.053, training accuracy: 47.77%
# 2024-02-26 10:26:16.712 | INFO     | trainer:train:56 - [TRN] Epoch: 50, training loss: 2.083, training accuracy: 43.85%
# 2024-02-26 10:26:16.779 | INFO     | trainer:train:56 - [TRN] Epoch: 51, training loss: 2.091, training accuracy: 46.37%
# 2024-02-26 10:26:16.849 | INFO     | trainer:train:56 - [TRN] Epoch: 52, training loss: 2.035, training accuracy: 46.65%
# 2024-02-26 10:26:16.915 | INFO     | trainer:train:56 - [TRN] Epoch: 53, training loss: 2.057, training accuracy: 46.65%
# 2024-02-26 10:26:16.984 | INFO     | trainer:train:56 - [TRN] Epoch: 54, training loss: 2.071, training accuracy: 44.13%
# 2024-02-26 10:26:17.054 | INFO     | trainer:train:56 - [TRN] Epoch: 55, training loss: 2.040, training accuracy: 44.13%
# 2024-02-26 10:26:17.123 | INFO     | trainer:train:56 - [TRN] Epoch: 56, training loss: 2.042, training accuracy: 46.09%
# 2024-02-26 10:26:17.193 | INFO     | trainer:train:56 - [TRN] Epoch: 57, training loss: 2.051, training accuracy: 47.21%
# 2024-02-26 10:26:17.262 | INFO     | trainer:train:56 - [TRN] Epoch: 58, training loss: 2.019, training accuracy: 46.93%
# 2024-02-26 10:26:17.330 | INFO     | trainer:train:56 - [TRN] Epoch: 59, training loss: 2.093, training accuracy: 41.34%
# 2024-02-26 10:26:17.401 | INFO     | trainer:train:56 - [TRN] Epoch: 60, training loss: 2.063, training accuracy: 47.49%
# 2024-02-26 10:26:17.470 | INFO     | trainer:train:56 - [TRN] Epoch: 61, training loss: 2.002, training accuracy: 46.09%
# 2024-02-26 10:26:17.540 | INFO     | trainer:train:56 - [TRN] Epoch: 62, training loss: 2.018, training accuracy: 46.09%
# 2024-02-26 10:26:17.609 | INFO     | trainer:train:56 - [TRN] Epoch: 63, training loss: 2.000, training accuracy: 46.09%
# 2024-02-26 10:26:17.678 | INFO     | trainer:train:56 - [TRN] Epoch: 64, training loss: 2.037, training accuracy: 48.60%
# 2024-02-26 10:26:17.744 | INFO     | trainer:train:56 - [TRN] Epoch: 65, training loss: 2.001, training accuracy: 52.79%
# 2024-02-26 10:26:17.808 | INFO     | trainer:train:56 - [TRN] Epoch: 66, training loss: 1.989, training accuracy: 52.23%
# 2024-02-26 10:26:17.871 | INFO     | trainer:train:56 - [TRN] Epoch: 67, training loss: 2.001, training accuracy: 53.07%
# 2024-02-26 10:26:17.939 | INFO     | trainer:train:56 - [TRN] Epoch: 68, training loss: 2.024, training accuracy: 50.56%
# 2024-02-26 10:26:18.006 | INFO     | trainer:train:56 - [TRN] Epoch: 69, training loss: 2.011, training accuracy: 52.23%
# 2024-02-26 10:26:18.077 | INFO     | trainer:train:56 - [TRN] Epoch: 70, training loss: 1.974, training accuracy: 55.31%
# 2024-02-26 10:26:18.146 | INFO     | trainer:train:56 - [TRN] Epoch: 71, training loss: 1.949, training accuracy: 55.03%
# 2024-02-26 10:26:18.212 | INFO     | trainer:train:56 - [TRN] Epoch: 72, training loss: 1.993, training accuracy: 49.16%
# 2024-02-26 10:26:18.281 | INFO     | trainer:train:56 - [TRN] Epoch: 73, training loss: 2.015, training accuracy: 54.47%
# 2024-02-26 10:26:18.350 | INFO     | trainer:train:56 - [TRN] Epoch: 74, training loss: 1.981, training accuracy: 50.00%
# 2024-02-26 10:26:18.417 | INFO     | trainer:train:56 - [TRN] Epoch: 75, training loss: 1.902, training accuracy: 57.54%
# 2024-02-26 10:26:18.487 | INFO     | trainer:train:56 - [TRN] Epoch: 76, training loss: 1.989, training accuracy: 52.79%
# 2024-02-26 10:26:18.558 | INFO     | trainer:train:56 - [TRN] Epoch: 77, training loss: 2.025, training accuracy: 52.51%
# 2024-02-26 10:26:18.631 | INFO     | trainer:train:56 - [TRN] Epoch: 78, training loss: 1.994, training accuracy: 55.59%
# 2024-02-26 10:26:18.706 | INFO     | trainer:train:56 - [TRN] Epoch: 79, training loss: 1.981, training accuracy: 53.63%
# 2024-02-26 10:26:18.777 | INFO     | trainer:train:56 - [TRN] Epoch: 80, training loss: 1.916, training accuracy: 55.31%
# 2024-02-26 10:26:18.848 | INFO     | trainer:train:56 - [TRN] Epoch: 81, training loss: 2.069, training accuracy: 53.63%
# 2024-02-26 10:26:18.920 | INFO     | trainer:train:56 - [TRN] Epoch: 82, training loss: 1.945, training accuracy: 56.15%
# 2024-02-26 10:26:18.988 | INFO     | trainer:train:56 - [TRN] Epoch: 83, training loss: 1.925, training accuracy: 55.59%
# 2024-02-26 10:26:19.056 | INFO     | trainer:train:56 - [TRN] Epoch: 84, training loss: 1.952, training accuracy: 56.15%
# 2024-02-26 10:26:19.125 | INFO     | trainer:train:56 - [TRN] Epoch: 85, training loss: 1.918, training accuracy: 55.31%
# 2024-02-26 10:26:19.191 | INFO     | trainer:train:56 - [TRN] Epoch: 86, training loss: 2.012, training accuracy: 55.59%
# 2024-02-26 10:26:19.254 | INFO     | trainer:train:56 - [TRN] Epoch: 87, training loss: 1.973, training accuracy: 54.19%
# 2024-02-26 10:26:19.321 | INFO     | trainer:train:56 - [TRN] Epoch: 88, training loss: 2.011, training accuracy: 54.75%
# 2024-02-26 10:26:19.390 | INFO     | trainer:train:56 - [TRN] Epoch: 89, training loss: 1.944, training accuracy: 56.15%
# 2024-02-26 10:26:19.460 | INFO     | trainer:train:56 - [TRN] Epoch: 90, training loss: 1.942, training accuracy: 50.28%
# 2024-02-26 10:26:19.528 | INFO     | trainer:train:56 - [TRN] Epoch: 91, training loss: 2.003, training accuracy: 53.07%
# 2024-02-26 10:26:19.605 | INFO     | trainer:train:56 - [TRN] Epoch: 92, training loss: 2.004, training accuracy: 51.68%
# 2024-02-26 10:26:19.696 | INFO     | trainer:train:56 - [TRN] Epoch: 93, training loss: 1.962, training accuracy: 53.91%
# 2024-02-26 10:26:19.801 | INFO     | trainer:train:56 - [TRN] Epoch: 94, training loss: 2.020, training accuracy: 54.19%
# 2024-02-26 10:26:19.899 | INFO     | trainer:train:56 - [TRN] Epoch: 95, training loss: 1.903, training accuracy: 55.31%
# 2024-02-26 10:26:19.980 | INFO     | trainer:train:56 - [TRN] Epoch: 96, training loss: 1.947, training accuracy: 54.47%
# 2024-02-26 10:26:20.047 | INFO     | trainer:train:56 - [TRN] Epoch: 97, training loss: 1.923, training accuracy: 55.59%
# 2024-02-26 10:26:20.117 | INFO     | trainer:train:56 - [TRN] Epoch: 98, training loss: 2.011, training accuracy: 53.63%
# 2024-02-26 10:26:20.187 | INFO     | trainer:train:56 - [TRN] Epoch: 99, training loss: 1.966, training accuracy: 53.91%

# %% [markdown]
# Testing:

# %%
trainer.test(verbose=True)
# Out:
# 2024-02-26 10:26:20.622 | INFO     | trainer:test:75 - [TST] Testing accuracy: 58.57%
# 0.5857058320731146
